# %% [markdown]
# <a href="https://colab.research.google.com/github/trongtn2110/CS114.L21/blob/master/Colab/Linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**CS114.L21**
# ## Thành viên:
# >Nguyễn Thành Trọng - 19522410
# >
# >Đào Văn Tài - 19522148
# >
# >Ngô Gia Kiệt - 19521725
# ## Nguồn tham khảo:
# >[sklearn.linear_model.Lasso](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Lasso.html#sklearn.linear_model.Lasso)
# >
# >[sklearn.linear_model.Ridge](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Ridge.html#sklearn.linear_model.Ridge)
# >
# >[sklearn.preprocessing.StandardScaler](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html#sklearn.preprocessing.StandardScaler)

# %% [markdown]
# ##**Cung cấp các thư viện cần thiết**

# %%
import numpy as np
import pandas as pd
from sklearn import  linear_model
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %% [markdown]
# ##**Lấy data train và data test**

# %%
colnames = ['Size', 'Time']
dtrain = pd.read_csv("http://cs.uit.edu.vn/data2.txt",names=colnames)
dtest = pd.read_csv("http://cs.uit.edu.vn/data3.txt",names=colnames)
dtest2 = pd.read_csv("http://cs.uit.edu.vn/data4.txt",names=colnames)

# %% [markdown]
# ##**Xử lý data**

# %%
# Dữ liệu train từ data1
x_train = np.array(dtrain['Size']).reshape(-1,1)
y_train = np.array(dtrain['Time'])

# Dữ liệu test data3
x_test = np.array(dtest['Size']).reshape(-1, 1)
y_test = np.array(dtest['Time'])

# Dữ liệu test data4
x_test2 = np.array(dtest2['Size']).reshape(-1, 1)
y_test2 = np.array(dtest2['Time'])

# %% [markdown]
# ##**Sử dụng phương pháp Feature Normalize và Linear Regression**

# %%
model = linear_model.LinearRegression()
scale = StandardScaler()
X_s_train = scale.fit_transform(x_train)
X_s_test = scale.transform(x_test)
X_s_test2 = scale.transform(x_test2)
model.fit(X_s_train,y_train)
y_pred = model.predict(X_s_test)
y_pred2 = model.predict(X_s_test2)
print('data3: ')
print('mean square error: ', mean_squared_error(y_test,y_pred))
print('the coefficient of determination: ',model.score(X_s_test,y_test))
print('data4: ')
print('mean square error: ', mean_squared_error(y_test2,y_pred2))
print('the coefficient of determination: ',model.score(X_s_test2,y_test2))
# Out:
# data3:
# mean square error:  0.020664949397549173
# the coefficient of determination:  0.9284132208349449
# data4:
# mean square error:  0.22348476817426075
# the coefficient of determination:  0.315683960536585

# %% [markdown]
# ##**Đồ thị**

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (40,10))
ax1.plot(X_s_test, y_test, 'r.' )
ax1.plot(X_s_test, y_pred,'b', linewidth=5)
ax1.set_title("Data3")
ax1.set(xlabel='Size', ylabel='Time')


ax2.plot(X_s_test2, y_test2, 'r.')
ax2.plot(X_s_test2, y_pred2, 'b', linewidth=5)
ax2.set_title("Data4")
ax2.set(xlabel='Size', ylabel='Time')

plt.show()

# %% [markdown]
# ##**Sử dụng phương pháp Feature Normalize và Lasso**

# %%
model = linear_model.Lasso(alpha= -0.02)
model.fit(X_s_train,y_train)
y_pred = model.predict(X_s_test)
y_pred2 = model.predict(X_s_test2)
print('data3: ')
print('mean square error: ', mean_squared_error(y_test,y_pred))
print('the coefficient of determination: ',model.score(X_s_test,y_test))
print('data4: ')
print('mean square error: ', mean_squared_error(y_test2,y_pred2))
print('the coefficient of determination: ',model.score(X_s_test2,y_test2))
# Out:
# data3:
# mean square error:  0.0060438111661747515
# the coefficient of determination:  0.9790632453559476
# data4:
# mean square error:  0.02015609131134164
# the coefficient of determination:  0.9382815361873559

# %% [markdown]
# ##**Đồ thị**

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (40,10))
ax1.plot(X_s_test, y_test, 'r.' )
ax1.plot(X_s_test, y_pred,'b', linewidth=5)
ax1.set_title("Data3")
ax1.set(xlabel='Size', ylabel='Time')


ax2.plot(X_s_test2, y_test2, 'r.')
ax2.plot(X_s_test2, y_pred2, 'b', linewidth=5)
ax2.set_title("Data4")
ax2.set(xlabel='Size', ylabel='Time')

plt.show()

# %% [markdown]
#  ## **Sử dụng phương pháp Feature Normalize và Regularization**

# %%
model = linear_model.Ridge(alpha= -5000)
model.fit(X_s_train,y_train)
y_pred = model.predict(X_s_test)
y_pred2 = model.predict(X_s_test2)
print('data3: ')
print('mean square error: ', mean_squared_error(y_test,y_pred))
print('the coefficient of determination: ',model.score(X_s_test,y_test))
print('data4: ')
print('mean square error: ', mean_squared_error(y_test2,y_pred2))
print('the coefficient of determination: ',model.score(X_s_test2,y_test2))
# Out:
# data3:
# mean square error:  0.004902732261706554
# the coefficient of determination:  0.9830161301161568
# data4:
# mean square error:  0.025449066129775266
# the coefficient of determination:  0.9220743127854201

# %% [markdown]
# ##**Đồ thị**

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (40,10))
ax1.plot(X_s_test, y_test, 'r.' )
ax1.plot(X_s_test, y_pred,color='blue', linewidth=5)
ax1.set_title("Data3")
ax1.set(xlabel='Size', ylabel='Time')


ax2.plot(X_s_test2, y_test2, 'r.')
ax2.plot(X_s_test2, y_pred2, color='blue', linewidth=5)
ax2.set_title("Data4")
ax2.set(xlabel='Size', ylabel='Time')

plt.show()
